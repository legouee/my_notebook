# %%
# !rm My_first_dataset_neo9.nwb

# %%
import neo
from neo import *
import pynwb
from pynwb import *
import quantities as pq
from quantities import s, ms, kHz, Hz, uV
import numpy as np
print("neo = ", neo.__version__)
print("pynwb = ", pynwb.__version__)
# Out:
# neo =  0.9.0.dev
# pynwb =  1.1.2

# %% [markdown]
# # Create a nwb file from Neo

# %% [markdown]
# ## Create 3 Neo blocks and populate each block with 4 Neo segments, and each segment with 3 Neo analogsignals objects and 2 Neo spiketrains

# %%
blocks = []

# Define Neo blocks
bl0 = neo.Block(name='First block')
bl1 = neo.Block(name='Second block')
bl2 = neo.Block(name='Third block')
print("bl0.segments = ", bl0.segments)      
print("bl1.segments = ", bl1.segments)
print("bl2.segments = ", bl2.segments)
blocks = [bl0, bl1, bl2]
print("blocks = ", blocks)

num_seg = 4 # number of segments
num_sig = 3 # number of signals

"""
# By giving a name to each blocks, segments, analogsignals, spiketrains, epochs
for blk in blocks: 
    print("blk = ", blk)
    
    for ind in range(num_seg): # number of Segment
        seg = Segment(name='segment %s %d' % (blk.name, ind), index=ind)
        blk.segments.append(seg)

    for seg in blk.segments: # AnalogSignal objects
        for ind2 in range(num_sig):
            #print("ind2 = ", ind2)
            print("seg = ", seg)
            # 3 Neo AnalogSignals
            a = AnalogSignal(name='analogsignal %s %s %d' % (blk.name, seg.name, ind2), index=ind2, signal=np.random.randn(num_seg, 44)*pq.nA, sampling_rate=10*kHz)
            #print("a.name = ", a.name)
            b = AnalogSignal(name='analogsignal %s %s %d' % (blk.name, seg.name, ind2), index=ind2, signal=np.random.randn(num_seg, 64)*pq.nA, sampling_rate=10*kHz)
            c = AnalogSignal(name='analogsignal %s %s %d' % (blk.name, seg.name, ind2), index=ind2, signal=np.random.randn(num_seg, 33)*pq.nA, sampling_rate=10*kHz)

            # 2 Neo SpikeTrains
            train = SpikeTrain(name='spiketrain %s %s %d' % (blk.name, seg.name, ind2), index=ind2, times=[1, 2, 3]*s, t_start=1.0, t_stop=10.0)
            print("train = ", train)
            print("train.name = ", train.name)
            train2 = SpikeTrain(name='spiketrain %s %s %d' % (blk.name, seg.name, ind2), index=ind2, times=[4, 5, 6]*s, t_stop=10.0)
            print("train2 = ", train2)
        
    #        train.annotate(channel_index=i)
    
            # 2 Neo Epoch
            epc = Epoch(name='epoch %s %s %d' % (blk.name, seg.name, ind2), index=ind2, times=np.arange(0, 30, 10)*s,
                        durations=[10, 5, 7]*ms,
                        labels=np.array(['btn0', 'btn1', 'btn2'], dtype='S'))
            print("epc = ", epc)
           
            epc2 = Epoch(name='epoch %s %s %d' % (blk.name, seg.name, ind2), index=ind2, times=np.arange(10, 40, 10)*s,
                        durations=[9, 3, 8]*ms,
                        labels=np.array(['btn3', 'btn4', 'btn5'], dtype='S'))    
            print("epc2 = ", epc2)      

        seg.spiketrains.append(train)
        seg.spiketrains.append(train2)

        seg.epochs.append(epc)
        seg.epochs.append(epc2)
        
        seg.analogsignals.append(a)
        seg.analogsignals.append(b)
        seg.analogsignals.append(c)
        
blocks
"""

            
            

# Without names

for blk in blocks: 
    print("blk = ", blk)
    
    for ind in range(num_seg): # number of Segment
        seg = Segment(name='segment %s %d' % (blk.name, ind), index=ind)
        blk.segments.append(seg)

    for seg in blk.segments: # AnalogSignal objects
        
        # 3 Neo AnalogSignals
        a = AnalogSignal(np.random.randn(num_seg, 44)*pq.nA, sampling_rate=10*kHz)
        b = AnalogSignal(np.random.randn(num_seg, 64)*pq.nA, sampling_rate=10*kHz)
        c = AnalogSignal(np.random.randn(num_seg, 33)*pq.nA, sampling_rate=10*kHz)

        # 2 Neo SpikeTrains
        train = SpikeTrain(times=[1, 2, 3]*s, t_start=1.0, t_stop=10.0)        
        train2 = SpikeTrain(times=[4, 5, 6]*s, t_stop=10.0)
    
        # 2 Neo Epoch
        epc = Epoch(times=np.arange(0, 30, 10)*s,
                    durations=[10, 5, 7]*ms,
                    labels=np.array(['btn0', 'btn1', 'btn2'], dtype='S'))
        print("epc = ", epc)
           
        epc2 = Epoch(times=np.arange(10, 40, 10)*s,
                    durations=[9, 3, 8]*ms,
                    labels=np.array(['btn3', 'btn4', 'btn5'], dtype='S'))    
        print("epc2 = ", epc2)

            
        seg.spiketrains.append(train)
        seg.spiketrains.append(train2)

        seg.epochs.append(epc)
        seg.epochs.append(epc2)
        
        seg.analogsignals.append(a)
        seg.analogsignals.append(b)
        seg.analogsignals.append(c)
        
blocks
# Out:
# bl0.segments =  []
# bl1.segments =  []
# bl2.segments =  []
# blocks =  [<neo.core.block.Block object at 0x7fd0fef45048>, <neo.core.block.Block object at 0x7fd0fef450b8>, <neo.core.block.Block object at 0x7fd0fef45128>]
# blk =  <neo.core.block.Block object at 0x7fd0fef45048>
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# blk =  <neo.core.block.Block object at 0x7fd0fef450b8>
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# blk =  <neo.core.block.Block object at 0x7fd0fef45128>
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# epc =  [ 0. 10. 20.] s
# epc2 =  [10. 20. 30.] s
# [Block with 4 segments
#  name: 'First block'
#  # segments (N=4)
#  0: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment First block 0'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#  1: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment First block 1'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#  2: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment First block 2'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#  3: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment First block 3'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004,
#  Block with 4 segments
#  name: 'Second block'
#  # segments (N=4)
#  0: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment Second block 0'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#  1: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment Second block 1'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#  2: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment Second block 2'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#  3: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment Second block 3'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004,
#  Block with 4 segments
#  name: 'Third block'
#  # segments (N=4)
#  0: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment Third block 0'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#  1: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment Third block 1'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#  2: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment Third block 2'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#  3: Segment with 3 analogsignals, 2 epochs, 2 spiketrains
#     name: 'segment Third block 3'
#     # analogsignals (N=3)
#     0: AnalogSignal with 44 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     1: AnalogSignal with 64 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004
#     2: AnalogSignal with 33 channels of length 4; units nA; datatype float64
#        sampling rate: 10.0
#        time: 0.0 to 0.0004]

# %% [markdown]
# # Write a nwb file

# %% [markdown]
# ## Using Neo NWBIO

# %%
filename='My_first_dataset_neo9.nwb'

# %%
writer = NWBIO(filename, mode='w')
writer.write(blocks)
# Out:
# /home/elodie/miniconda2/envs/env_NWB_py3_pynwb_1_1_2/lib/python3.6/site-packages/pynwb/file.py:691: UserWarning: Date is missing timezone information. Updating to local timezone.
#   warn("Date is missing timezone information. Updating to local timezone.")
# /home/elodie/miniconda2/envs/env_NWB_py3_pynwb_1_1_2/lib/python3.6/site-packages/hdmf/build/map.py:949: MissingRequiredWarning: attribute 'unit' for 'data' (TimeSeries)
#   warnings.warn(msg, MissingRequiredWarning)

# %%
writer

# %% [markdown]
# # Read the NWB file

# %% [markdown]
# ## Using pynwb

# %%
io = pynwb.NWBHDF5IO(filename, mode='r') # Open a file with NWBHDF5IO
_file = io.read()

# %%
_file
# Out:
# root pynwb.file.NWBFile at 0x140535607417488
# Fields:
#   acquisition: {
#     analogsignal First block segment First block 0 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal First block segment First block 1 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal First block segment First block 2 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal First block segment First block 3 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Second block segment Second block 0 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Second block segment Second block 1 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Second block segment Second block 2 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Second block segment Second block 3 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Third block segment Third block 0 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Third block segment Third block 1 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Third block segment Third block 2 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Third block segment Third block 3 2 <class 'pynwb.base.TimeSeries'>,
#     neo epochs First block segment First block 0 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs First block segment First block 1 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs First block segment First block 2 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs First block segment First block 3 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Second block segment Second block 0 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Second block segment Second block 1 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Second block segment Second block 2 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Second block segment Second block 3 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Third block segment Third block 0 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Third block segment Third block 1 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Third block segment Third block 2 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Third block segment Third block 3 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains First block segment First block 0 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains First block segment First block 1 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains First block segment First block 2 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains First block segment First block 3 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Second block segment Second block 0 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Second block segment Second block 1 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Second block segment Second block 2 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Second block segment Second block 3 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Third block segment Third block 0 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Third block segment Third block 1 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Third block segment Third block 2 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Third block segment Third block 3 1 <class 'pynwb.base.TimeSeries'>
#   }
#   epochs: epochs <class 'pynwb.epoch.TimeIntervals'>
#   file_create_date: [datetime.datetime(2020, 1, 27, 14, 32, 37, 854166, tzinfo=tzoffset(None, 3600))]
#   intervals: {
#     epochs <class 'pynwb.epoch.TimeIntervals'>
#   }
#   session_description: My_first_dataset_neo9.nwb
#   session_start_time: 2020-01-27 14:32:37.851192+01:00
#   timestamps_reference_time: 2020-01-27 14:32:37.851192+01:00

# %%
print(_file)
_file.acquisition
# Out:
# root pynwb.file.NWBFile at 0x140535607417488
# Fields:
#   acquisition: {
#     analogsignal First block segment First block 0 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal First block segment First block 1 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal First block segment First block 2 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal First block segment First block 3 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Second block segment Second block 0 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Second block segment Second block 1 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Second block segment Second block 2 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Second block segment Second block 3 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Third block segment Third block 0 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Third block segment Third block 1 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Third block segment Third block 2 2 <class 'pynwb.base.TimeSeries'>,
#     analogsignal Third block segment Third block 3 2 <class 'pynwb.base.TimeSeries'>,
#     neo epochs First block segment First block 0 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs First block segment First block 1 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs First block segment First block 2 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs First block segment First block 3 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Second block segment Second block 0 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Second block segment Second block 1 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Second block segment Second block 2 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Second block segment Second block 3 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Third block segment Third block 0 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Third block segment Third block 1 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Third block segment Third block 2 1 <class 'pynwb.base.TimeSeries'>,
#     neo epochs Third block segment Third block 3 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains First block segment First block 0 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains First block segment First block 1 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains First block segment First block 2 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains First block segment First block 3 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Second block segment Second block 0 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Second block segment Second block 1 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Second block segment Second block 2 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Second block segment Second block 3 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Third block segment Third block 0 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Third block segment Third block 1 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Third block segment Third block 2 1 <class 'pynwb.base.TimeSeries'>,
#     spiketrains Third block segment Third block 3 1 <class 'pynwb.base.TimeSeries'>
#   }
#   epochs: epochs <class 'pynwb.epoch.TimeIntervals'>
#   file_create_date: [datetime.datetime(2020, 1, 27, 14, 32, 37, 854166, tzinfo=tzoffset(None, 3600))]
#   intervals: {
#     epochs <class 'pynwb.epoch.TimeIntervals'>
#   }
#   session_description: My_first_dataset_neo9.nwb
#   session_start_time: 2020-01-27 14:32:37.851192+01:00
#   timestamps_reference_time: 2020-01-27 14:32:37.851192+01:00
# {'analogsignal First block segment First block 0 2': analogsignal First block segment First block 0 2 pynwb.base.TimeSeries at 0x140535602717248
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal First block segment First block 1 2': analogsignal First block segment First block 1 2 pynwb.base.TimeSeries at 0x140535602718256
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal First block segment First block 2 2': analogsignal First block segment First block 2 2 pynwb.base.TimeSeries at 0x140535602719040
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal First block segment First block 3 2': analogsignal First block segment First block 3 2 pynwb.base.TimeSeries at 0x140535602719376
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal Second block segment Second block 0 2': analogsignal Second block segment Second block 0 2 pynwb.base.TimeSeries at 0x140535602719712
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal Second block segment Second block 1 2': analogsignal Second block segment Second block 1 2 pynwb.base.TimeSeries at 0x140535602719600
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal Second block segment Second block 2 2': analogsignal Second block segment Second block 2 2 pynwb.base.TimeSeries at 0x140535602719936
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal Second block segment Second block 3 2': analogsignal Second block segment Second block 3 2 pynwb.base.TimeSeries at 0x140535602720160
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal Third block segment Third block 0 2': analogsignal Third block segment Third block 0 2 pynwb.base.TimeSeries at 0x140535602720384
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal Third block segment Third block 1 2': analogsignal Third block segment Third block 1 2 pynwb.base.TimeSeries at 0x140535602720328
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal Third block segment Third block 2 2': analogsignal Third block segment Third block 2 2 pynwb.base.TimeSeries at 0x140535602720552
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'analogsignal Third block segment Third block 3 2': analogsignal Third block segment Third block 3 2 pynwb.base.TimeSeries at 0x140535602720272
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs First block segment First block 0 1': neo epochs First block segment First block 0 1 pynwb.base.TimeSeries at 0x140535602720440
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs First block segment First block 1 1': neo epochs First block segment First block 1 1 pynwb.base.TimeSeries at 0x140535602719992
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs First block segment First block 2 1': neo epochs First block segment First block 2 1 pynwb.base.TimeSeries at 0x140535602720720
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs First block segment First block 3 1': neo epochs First block segment First block 3 1 pynwb.base.TimeSeries at 0x140535602718928
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs Second block segment Second block 0 1': neo epochs Second block segment Second block 0 1 pynwb.base.TimeSeries at 0x140535602663888
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs Second block segment Second block 1 1': neo epochs Second block segment Second block 1 1 pynwb.base.TimeSeries at 0x140535602664112
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs Second block segment Second block 2 1': neo epochs Second block segment Second block 2 1 pynwb.base.TimeSeries at 0x140535602664336
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs Second block segment Second block 3 1': neo epochs Second block segment Second block 3 1 pynwb.base.TimeSeries at 0x140535602664560
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs Third block segment Third block 0 1': neo epochs Third block segment Third block 0 1 pynwb.base.TimeSeries at 0x140535602664784
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs Third block segment Third block 1 1': neo epochs Third block segment Third block 1 1 pynwb.base.TimeSeries at 0x140535602665008
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs Third block segment Third block 2 1': neo epochs Third block segment Third block 2 1 pynwb.base.TimeSeries at 0x140535602665232
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'neo epochs Third block segment Third block 3 1': neo epochs Third block segment Third block 3 1 pynwb.base.TimeSeries at 0x140535602665456
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains First block segment First block 0 1': spiketrains First block segment First block 0 1 pynwb.base.TimeSeries at 0x140535602665680
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains First block segment First block 1 1': spiketrains First block segment First block 1 1 pynwb.base.TimeSeries at 0x140535602665904
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains First block segment First block 2 1': spiketrains First block segment First block 2 1 pynwb.base.TimeSeries at 0x140535602666128
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains First block segment First block 3 1': spiketrains First block segment First block 3 1 pynwb.base.TimeSeries at 0x140535602666352
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains Second block segment Second block 0 1': spiketrains Second block segment Second block 0 1 pynwb.base.TimeSeries at 0x140535602666576
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains Second block segment Second block 1 1': spiketrains Second block segment Second block 1 1 pynwb.base.TimeSeries at 0x140535602666800
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains Second block segment Second block 2 1': spiketrains Second block segment Second block 2 1 pynwb.base.TimeSeries at 0x140535602667024
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains Second block segment Second block 3 1': spiketrains Second block segment Second block 3 1 pynwb.base.TimeSeries at 0x140535602667248
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains Third block segment Third block 0 1': spiketrains Third block segment Third block 0 1 pynwb.base.TimeSeries at 0x140535602667472
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains Third block segment Third block 1 1': spiketrains Third block segment Third block 1 1 pynwb.base.TimeSeries at 0x140535602667360
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains Third block segment Third block 2 1': spiketrains Third block segment Third block 2 1 pynwb.base.TimeSeries at 0x140535602680272
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds,
#  'spiketrains Third block segment Third block 3 1': spiketrains Third block segment Third block 3 1 pynwb.base.TimeSeries at 0x140535602680496
#  Fields:
#    comments: no comments
#    conversion: 1.0
#    data: <HDF5 dataset "data": shape (3,), type "<f8">
#    interval: 1
#    resolution: -1.0
#    timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#    timestamps_unit: seconds}

# %%
print("_file.epochs = ", _file.epochs)
# Out:
# _file.epochs =  epochs pynwb.epoch.TimeIntervals at 0x140535602680440
# Fields:
#   colnames: ['start_time' 'stop_time' 'tags']
#   columns: (
#     start_time <class 'hdmf.common.table.VectorData'>,
#     stop_time <class 'hdmf.common.table.VectorData'>,
#     tags_index <class 'hdmf.common.table.VectorIndex'>,
#     tags <class 'hdmf.common.table.VectorData'>
#   )
#   description: experimental epochs
#   id: id <class 'hdmf.common.table.ElementIdentifiers'>

# %%
_file.epochs
# Out:
# epochs pynwb.epoch.TimeIntervals at 0x140535602680440
# Fields:
#   colnames: ['start_time' 'stop_time' 'tags']
#   columns: (
#     start_time <class 'hdmf.common.table.VectorData'>,
#     stop_time <class 'hdmf.common.table.VectorData'>,
#     tags_index <class 'hdmf.common.table.VectorIndex'>,
#     tags <class 'hdmf.common.table.VectorData'>
#   )
#   description: experimental epochs
#   id: id <class 'hdmf.common.table.ElementIdentifiers'>

# %%
#print("_file.units = ", _file.units)
#print("   ")
#print("----")
#print("_file.units[0] = ", _file.units[0])
#print("_file.units[1] = ", _file.units[1])

# %%
#for a in _file.units:
#    print("a = ", a)
#    print("_file.units[0] = ", _file.units[0])
#    print("_file.units[1] = ", _file.units[1])

# %%
#for j in _file.epochs:
#    print("j = ", j)    
#    print("   ")
#    for w in _file.acquisition:
#        print("w.data = ", w.data)

# %% [markdown]
# ## Using Neo NWBIO

# %%
reader = NWBIO(filename, mode='r')

# %%
reader

# %%
all_blocks = reader.read()
# Out:
# node =  {'analogsignal First block segment First block 0 2': analogsignal First block segment First block 0 2 pynwb.base.TimeSeries at 0x140535599379176
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal First block segment First block 1 2': analogsignal First block segment First block 1 2 pynwb.base.TimeSeries at 0x140535599380576
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal First block segment First block 2 2': analogsignal First block segment First block 2 2 pynwb.base.TimeSeries at 0x140535599380408
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal First block segment First block 3 2': analogsignal First block segment First block 3 2 pynwb.base.TimeSeries at 0x140535599380688
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal Second block segment Second block 0 2': analogsignal Second block segment Second block 0 2 pynwb.base.TimeSeries at 0x140535599380912
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal Second block segment Second block 1 2': analogsignal Second block segment Second block 1 2 pynwb.base.TimeSeries at 0x140535599381136
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal Second block segment Second block 2 2': analogsignal Second block segment Second block 2 2 pynwb.base.TimeSeries at 0x140535599381360
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal Second block segment Second block 3 2': analogsignal Second block segment Second block 3 2 pynwb.base.TimeSeries at 0x140535599381584
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal Third block segment Third block 0 2': analogsignal Third block segment Third block 0 2 pynwb.base.TimeSeries at 0x140535599381808
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal Third block segment Third block 1 2': analogsignal Third block segment Third block 1 2 pynwb.base.TimeSeries at 0x140535599382032
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal Third block segment Third block 2 2': analogsignal Third block segment Third block 2 2 pynwb.base.TimeSeries at 0x140535599382256
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'analogsignal Third block segment Third block 3 2': analogsignal Third block segment Third block 3 2 pynwb.base.TimeSeries at 0x140535599382480
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs First block segment First block 0 1': neo epochs First block segment First block 0 1 pynwb.base.TimeSeries at 0x140535599382368
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs First block segment First block 1 1': neo epochs First block segment First block 1 1 pynwb.base.TimeSeries at 0x140535599522256
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs First block segment First block 2 1': neo epochs First block segment First block 2 1 pynwb.base.TimeSeries at 0x140535599522480
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs First block segment First block 3 1': neo epochs First block segment First block 3 1 pynwb.base.TimeSeries at 0x140535599522704
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs Second block segment Second block 0 1': neo epochs Second block segment Second block 0 1 pynwb.base.TimeSeries at 0x140535599522928
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs Second block segment Second block 1 1': neo epochs Second block segment Second block 1 1 pynwb.base.TimeSeries at 0x140535599523152
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs Second block segment Second block 2 1': neo epochs Second block segment Second block 2 1 pynwb.base.TimeSeries at 0x140535599523376
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs Second block segment Second block 3 1': neo epochs Second block segment Second block 3 1 pynwb.base.TimeSeries at 0x140535599523600
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs Third block segment Third block 0 1': neo epochs Third block segment Third block 0 1 pynwb.base.TimeSeries at 0x140535599523824
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs Third block segment Third block 1 1': neo epochs Third block segment Third block 1 1 pynwb.base.TimeSeries at 0x140535599524048
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs Third block segment Third block 2 1': neo epochs Third block segment Third block 2 1 pynwb.base.TimeSeries at 0x140535599524272
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'neo epochs Third block segment Third block 3 1': neo epochs Third block segment Third block 3 1 pynwb.base.TimeSeries at 0x140535599524496
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (4, 33), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (4,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains First block segment First block 0 1': spiketrains First block segment First block 0 1 pynwb.base.TimeSeries at 0x140535599524720
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains First block segment First block 1 1': spiketrains First block segment First block 1 1 pynwb.base.TimeSeries at 0x140535599524944
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains First block segment First block 2 1': spiketrains First block segment First block 2 1 pynwb.base.TimeSeries at 0x140535599525168
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains First block segment First block 3 1': spiketrains First block segment First block 3 1 pynwb.base.TimeSeries at 0x140535599525392
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains Second block segment Second block 0 1': spiketrains Second block segment Second block 0 1 pynwb.base.TimeSeries at 0x140535599525616
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains Second block segment Second block 1 1': spiketrains Second block segment Second block 1 1 pynwb.base.TimeSeries at 0x140535599525840
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains Second block segment Second block 2 1': spiketrains Second block segment Second block 2 1 pynwb.base.TimeSeries at 0x140535599525728
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains Second block segment Second block 3 1': spiketrains Second block segment Second block 3 1 pynwb.base.TimeSeries at 0x140535599423952
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains Third block segment Third block 0 1': spiketrains Third block segment Third block 0 1 pynwb.base.TimeSeries at 0x140535599424176
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains Third block segment Third block 1 1': spiketrains Third block segment Third block 1 1 pynwb.base.TimeSeries at 0x140535599424400
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains Third block segment Third block 2 1': spiketrains Third block segment Third block 2 1 pynwb.base.TimeSeries at 0x140535599424624
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# , 'spiketrains Third block segment Third block 3 1': spiketrains Third block segment Third block 3 1 pynwb.base.TimeSeries at 0x140535599424848
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (3,), type "<f8">
#   interval: 1
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (1,), type "<f8">
#   timestamps_unit: seconds
# }
# node =  None
# node =  epochs pynwb.epoch.TimeIntervals at 0x140535599424792
# Fields:
#   colnames: ['start_time' 'stop_time' 'tags']
#   columns: (
#     start_time <class 'hdmf.common.table.VectorData'>,
#     stop_time <class 'hdmf.common.table.VectorData'>,
#     tags_index <class 'hdmf.common.table.VectorIndex'>,
#     tags <class 'hdmf.common.table.VectorData'>
#   )
#   description: experimental epochs
#   id: id <class 'hdmf.common.table.ElementIdentifiers'>

# %%
all_blocks
# Out:
# [Block with 1 segments
#  description: 'My_first_dataset_neo9.nwb'
#  annotations: {'file_access_dates': [datetime.datetime(2020, 1, 27, 14, 32, 37, 854166, tzinfo=tzoffset(None, 3600))],
#    'file_read_log': ''}
#  file_origin: 'My_first_dataset_neo9.nwb'
#  file_datetime: [datetime.datetime(2020, 1, 27, 14, 32, 37, 854166, tzinfo=tzoffset(None, 3600))]
#  rec_datetime: datetime.datetime(2020, 1, 27, 14, 32, 37, 851192, tzinfo=tzoffset(None, 3600))
#  # segments (N=1)
#  0: Segment with 1 epochs name: 'NeoNWB IO' # analogsignals (N=0),
#  Block with 1 segments
#  description: 'My_first_dataset_neo9.nwb'
#  annotations: {'file_access_dates': [datetime.datetime(2020, 1, 27, 14, 32, 37, 854166, tzinfo=tzoffset(None, 3600))],
#    'file_read_log': ''}
#  file_origin: 'My_first_dataset_neo9.nwb'
#  file_datetime: [datetime.datetime(2020, 1, 27, 14, 32, 37, 854166, tzinfo=tzoffset(None, 3600))]
#  rec_datetime: datetime.datetime(2020, 1, 27, 14, 32, 37, 851192, tzinfo=tzoffset(None, 3600))
#  # segments (N=1)
#  0: Segment with 1 epochs name: 'NeoNWB IO' # analogsignals (N=0),
#  Block with 1 segments
#  description: 'My_first_dataset_neo9.nwb'
#  annotations: {'file_access_dates': [datetime.datetime(2020, 1, 27, 14, 32, 37, 854166, tzinfo=tzoffset(None, 3600))],
#    'file_read_log': ''}
#  file_origin: 'My_first_dataset_neo9.nwb'
#  file_datetime: [datetime.datetime(2020, 1, 27, 14, 32, 37, 854166, tzinfo=tzoffset(None, 3600))]
#  rec_datetime: datetime.datetime(2020, 1, 27, 14, 32, 37, 851192, tzinfo=tzoffset(None, 3600))
#  # segments (N=1)
#  0: Segment with 1 epochs name: 'NeoNWB IO' # analogsignals (N=0)]

# %%
#first_block = reader.read_block() # Read the first block

# %%
#first_block

# %%
# Plotting settings
show_bar_plot = False    # Change setting to plot distribution of object sizes in the HDF5 file
plot_single_file = True # Plot all files or a single example file
output_filenames = filename
print("output_filenames = ", output_filenames)
    
# Select the files to plot
filenames = output_filenames
print("filenames = ", filenames)

from utils.render import HierarchyDescription, NXGraphHierarchyDescription
import matplotlib.pyplot as plt
        
# Create the plots for all files
file_hierarchy = HierarchyDescription.from_hdf5(filenames)
file_graph = NXGraphHierarchyDescription(file_hierarchy)          
fig = file_graph.draw(show_plot=False,
                      figsize=(12,16),
                      label_offset=(0.0, 0.0065),
                      label_font_size=10)
plot_title = filenames + " \n " + "#Datasets=%i, #Attributes=%i, #Groups=%i, #Links=%i" % (len(file_hierarchy['datasets']), len(file_hierarchy['attributes']), len(file_hierarchy['groups']), len(file_hierarchy['links']))
plt.title(plot_title)
plt.show()
        
# Show a sorted bar plot with the sizes of all datasets in the file
if show_bar_plot:
    d = {i['name']: np.prod(i['size']) for i in file_hierarchy['datasets']}
    l = [w for w in sorted(d, key=d.get, reverse=True)]
    s = [d[w] for w in l]   
    p = np.arange(len(l))   
    fig,ax = plt.subplots(figsize=(16,7))
    ax.set_title(filename)
    ax.bar(p, s, width=1, color='r')
    ax.set_xticks(p+1)  
    ax.set_xticklabels(l)  
    ax.set_yscale("log", nonposy='clip')
    fig.autofmt_xdate(bottom=0.2, rotation=90, ha='right')
    plt.show()
plt.show()
# Out:
# output_filenames =  My_first_dataset_neo9.nwb
# filenames =  My_first_dataset_neo9.nwb

# %%
io.read_builder()
# Out:
# {'acquisition': {'analogsignal First block segment First block 0 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '2a01d248-1932-4ad5-9c17-1259b8b9d8bf',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal First block segment First block 1 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'fdef4a81-5197-4a25-a334-0babe1527775',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal First block segment First block 2 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'ab2a704f-9e8c-4375-a1c1-c4c1f6e897e7',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal First block segment First block 3 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '5be773dd-a5c7-49a4-9f62-fd0826b0d3b4',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal Second block segment Second block 0 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'ca1dcff8-6fb1-4552-af16-35b4655145e8',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal Second block segment Second block 1 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '5db2d3c3-c18a-4fda-96bf-ba2fd4bb5ff2',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal Second block segment Second block 2 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '99c83357-da02-4a96-9b9a-fe1db6286ae1',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal Second block segment Second block 3 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '17b93cff-208d-49a9-a65b-be1e070f65d3',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal Third block segment Third block 0 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'dc28c826-9b62-4c84-88e4-c1abb49cb772',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal Third block segment Third block 1 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '3268744c-ec2d-4984-9294-73a64013a020',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal Third block segment Third block 2 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '2d98c137-e0f5-4e44-814e-60aaa2b29492',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'analogsignal Third block segment Third block 3 2': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '108f93ec-28ce-4dd8-96e8-c94246c57107',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'neo epochs First block segment First block 0 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '9a317dfc-7d37-47a7-9309-b41ce03ff7c0',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs First block segment First block 1 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '55d59592-34f2-46f1-bfa3-aed7dd0aa4b2',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs First block segment First block 2 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'd6059c81-6928-465f-b5e2-178c93cb7e74',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs First block segment First block 3 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'f41ede2e-28f3-4ba9-846f-48b232bc49eb',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs Second block segment Second block 0 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '22aa72cd-59cc-49f8-be10-26d5d2b3a2cb',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs Second block segment Second block 1 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'aed07960-49e8-4948-81fa-61c8e42cd4f3',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs Second block segment Second block 2 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '5fe79d46-57ad-4512-a158-c6deb8c81e8d',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs Second block segment Second block 3 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '663d37f6-5075-4336-8313-838a69c80c5b',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs Third block segment Third block 0 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '8a23e3dd-d94b-4a25-80cf-6934bcca3e35',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs Third block segment Third block 1 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'bc193879-0771-44c7-9277-2a600444260c',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs Third block segment Third block 2 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'dc098a89-ff99-423d-ac9e-6905fb549243',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'neo epochs Third block segment Third block 3 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (4, 33), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'a2473aac-14b3-4d51-ae00-dce1a8068577',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (4,), type "<f8">}},
#   'spiketrains First block segment First block 0 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '13a050bb-d165-427b-bcf7-41b021386b08',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains First block segment First block 1 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '4d04e821-09f8-4284-bc31-f04980441ad1',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains First block segment First block 2 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '73e78901-4805-4cfa-ae32-215ff4762fb6',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains First block segment First block 3 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '8671e378-3f1c-4e23-b98d-89687fe558f5',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains Second block segment Second block 0 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'd42c7ec2-15e6-4b16-8d5b-56eee76ee639',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains Second block segment Second block 1 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'f748bab2-916e-44ac-a68a-728031d1e834',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains Second block segment Second block 2 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'facbd89c-73b5-415b-a69c-5ab93c9c3415',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains Second block segment Second block 3 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '7193f732-8a53-4109-8ee0-065a4de9bed6',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains Third block segment Third block 0 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'f5932776-c753-41dc-8eec-ba782a5fc8a0',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains Third block segment Third block 1 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': '6fa4b398-08bb-47bf-81c8-2678fa7806b5',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains Third block segment Third block 2 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'ab3fd0e0-8e98-402e-bb4d-5cfef6d25e31',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}},
#   'spiketrains Third block segment Third block 3 1': {'comments': 'no comments',
#    'data': {'attributes': {'conversion': 1.0, 'resolution': -1.0},
#     'data': <HDF5 dataset "data": shape (3,), type "<f8">},
#    'description': '',
#    'namespace': 'core',
#    'neurodata_type': 'TimeSeries',
#    'object_id': 'f92c9052-5c32-4b2e-8ba8-f1b1022c364f',
#    'timestamps': {'attributes': {'interval': 1, 'unit': 'seconds'},
#     'data': <HDF5 dataset "timestamps": shape (1,), type "<f8">}}},
#  'analysis': {},
#  'file_create_date': {'attributes': {},
#   'data': <HDF5 dataset "file_create_date": shape (1,), type "|O">},
#  'general': {},
#  'identifier': {'attributes': {}, 'data': ''},
#  'intervals': {'epochs': {'colnames': array([b'start_time', b'stop_time', b'tags'], dtype='|S13'),
#    'description': 'experimental epochs',
#    'id': {'attributes': {'namespace': 'hdmf-common',
#      'neurodata_type': 'ElementIdentifiers',
#      'object_id': '73c7bb69-12a5-4cc0-bfdc-fe3cd1705234'},
#     'data': <HDF5 dataset "id": shape (1,), type "<i8">},
#    'namespace': 'core',
#    'neurodata_type': 'TimeIntervals',
#    'object_id': '00ecb354-4600-41d0-a0d3-50d8625f53ac',
#    'start_time': {'attributes': {'description': 'Start time of epoch, in seconds',
#      'namespace': 'hdmf-common',
#      'neurodata_type': 'VectorData',
#      'object_id': '9bad1961-d2ba-4951-8190-c53d7a8c724a'},
#     'data': <HDF5 dataset "start_time": shape (1,), type "<f8">},
#    'stop_time': {'attributes': {'description': 'Stop time of epoch, in seconds',
#      'namespace': 'hdmf-common',
#      'neurodata_type': 'VectorData',
#      'object_id': 'c81561e5-db3f-4808-95b4-315b0489dd21'},
#     'data': <HDF5 dataset "stop_time": shape (1,), type "<f8">},
#    'tags': {'attributes': {'description': 'user-defined tags',
#      'namespace': 'hdmf-common',
#      'neurodata_type': 'VectorData',
#      'object_id': 'e06b6b6b-df98-4813-a718-60108d1d9958'},
#     'data': <HDF5 dataset "tags": shape (1,), type "|O">},
#    'tags_index': {'attributes': {'namespace': 'hdmf-common',
#      'neurodata_type': 'VectorIndex',
#      'object_id': '310f4ae2-e7ae-4237-891d-b8512af50fcd',
#      'target': {'attributes': {'description': 'user-defined tags',
#        'namespace': 'hdmf-common',
#        'neurodata_type': 'VectorData',
#        'object_id': 'e06b6b6b-df98-4813-a718-60108d1d9958'},
#       'data': <HDF5 dataset "tags": shape (1,), type "|O">}},
#     'data': <HDF5 dataset "tags_index": shape (1,), type "<i8">}}},
#  'namespace': 'core',
#  'neurodata_type': 'NWBFile',
#  'nwb_version': '2.1.0',
#  'object_id': '974ecd39-7488-4c5d-af33-9233847710ae',
#  'processing': {},
#  'session_description': {'attributes': {},
#   'data': 'My_first_dataset_neo9.nwb'},
#  'session_start_time': {'attributes': {},
#   'data': '2020-01-27T14:32:37.851192+01:00'},
#  'stimulus': {'presentation': {}, 'templates': {}},
#  'timestamps_reference_time': {'attributes': {},
#   'data': '2020-01-27T14:32:37.851192+01:00'}}
