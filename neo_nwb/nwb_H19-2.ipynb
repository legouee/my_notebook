# %%
# Requirements
# python = 3.6.2
# pynwb = 1.0.1

# %%
#################################
# NWB Packages
#################################

import numpy
import pynwb
from pynwb import NWBFile, TimeSeries, get_manager
from pynwb.spec import NWBGroupSpec, NWBDatasetSpec, NWBNamespace
from pynwb.base import ProcessingModule
from pynwb.ecephys import ElectrodeGroup, Device
from pynwb.image import ImageSeries
from pynwb.core import set_parents
from pynwb import *
from datetime import datetime
from pynwb import NWBFile #, TimeSeries, get_manager

# %%
#################################
# neo Packages
#################################

import neo
from neo import *
print ("neo.__version__ = ", neo.__version__)

import urllib
import numpy as np
import quantities as pq
from matplotlib import pyplot
import matplotlib.pyplot as plt
# Out:
# mode
# neo.__version__ =  0.8.0.dev

# %%
#################################
# NWB File
# http://download.alleninstitute.org/informatics-archive/prerelease/
# H19.28.012.11.05-2.nwb
#################################

# Read the NWB File
filename = "/home/elodie/NWB_Files/NWB_org/H19.28.012.11.05-2.nwb"
io2 = pynwb.NWBHDF5IO(filename, mode='r')
io2.read_builder()
# Out:
# {'acquisition': {'index_000': {'capacitance_fast': {'attributes': {'unit': 'A'},
#     'data': 0.0},
#    'capacitance_slow': {'attributes': {'unit': 'Farad'}, 'data': nan},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'A'},
#     'data': <HDF5 dataset "data": shape (70000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 5000000.0},
#    'resistance_comp_bandwidth': {'attributes': {'unit': 'Hz'}, 'data': nan},
#    'resistance_comp_correction': {'attributes': {'unit': 'pecent'},
#     'data': nan},
#    'resistance_comp_prediction': {'attributes': {'unit': 'pecent'},
#     'data': nan},
#    'starting_time': {'attributes': {'rate': 199999.99999999997,
#      'unit': 'Seconds'},
#     'data': 13008.059839},
#    'whole_cell_capacitance_comp': {'attributes': {'unit': 'Farad'},
#     'data': nan},
#    'whole_cell_series_resistance_comp': {'attributes': {'unit': 'Ohm'},
#     'data': nan},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2001001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "extpinbath",\n    "sweep_label": ""\n}',
#    'help': 'Current recorded from cell during voltage-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'VoltageClampSeries',
#    'stimulus_description': 'extpinbath',
#    'sweep_number': 2001001,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_001': {'capacitance_fast': {'attributes': {'unit': 'A'},
#     'data': 6.063405827748043e-12},
#    'capacitance_slow': {'attributes': {'unit': 'Farad'}, 'data': nan},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'A'},
#     'data': <HDF5 dataset "data": shape (70000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 50000000.0},
#    'resistance_comp_bandwidth': {'attributes': {'unit': 'Hz'}, 'data': nan},
#    'resistance_comp_correction': {'attributes': {'unit': 'pecent'},
#     'data': nan},
#    'resistance_comp_prediction': {'attributes': {'unit': 'pecent'},
#     'data': nan},
#    'starting_time': {'attributes': {'rate': 199999.99999999997,
#      'unit': 'Seconds'},
#     'data': 13251.517779},
#    'whole_cell_capacitance_comp': {'attributes': {'unit': 'Farad'},
#     'data': nan},
#    'whole_cell_series_resistance_comp': {'attributes': {'unit': 'Ohm'},
#     'data': nan},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2002001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "extpciiatt",\n    "sweep_label": ""\n}',
#    'help': 'Current recorded from cell during voltage-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'VoltageClampSeries',
#    'stimulus_description': 'extpciiatt',
#    'sweep_number': 2002001,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_002': {'capacitance_fast': {'attributes': {'unit': 'A'},
#     'data': 6.063405827748043e-12},
#    'capacitance_slow': {'attributes': {'unit': 'Farad'}, 'data': nan},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'A'},
#     'data': <HDF5 dataset "data": shape (70000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'resistance_comp_bandwidth': {'attributes': {'unit': 'Hz'}, 'data': nan},
#    'resistance_comp_correction': {'attributes': {'unit': 'pecent'},
#     'data': nan},
#    'resistance_comp_prediction': {'attributes': {'unit': 'pecent'},
#     'data': nan},
#    'starting_time': {'attributes': {'rate': 199999.99999999997,
#      'unit': 'Seconds'},
#     'data': 13287.819879},
#    'whole_cell_capacitance_comp': {'attributes': {'unit': 'Farad'},
#     'data': nan},
#    'whole_cell_series_resistance_comp': {'attributes': {'unit': 'Ohm'},
#     'data': nan},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2003001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "extpbreakn",\n    "sweep_label": ""\n}',
#    'help': 'Current recorded from cell during voltage-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'VoltageClampSeries',
#    'stimulus_description': 'extpbreakn',
#    'sweep_number': 2003001,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_003': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13288.833239},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004001,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_004': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13292.12488},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004002,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004002,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_005': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13295.4318},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004003,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004003,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_006': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13298.739679},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004004,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004004,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_007': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13302.046879},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004005,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004005,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_008': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13305.35316},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004006,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004006,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_009': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13308.661599},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004007,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004007,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_010': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13311.96852},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004008,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004008,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_011': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13315.275799},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004009,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004009,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_012': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13318.58284},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004010,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004010,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_013': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13321.889359},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004011,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004011,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_014': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13325.197719},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004012,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004012,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_015': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13328.566759},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004013,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004013,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_016': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13331.811558},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004014,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004014,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_017': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (300000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 99999.99999999999,
#      'unit': 'Seconds'},
#     'data': 13335.05688},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2004015,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Long square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Long square',
#    'sweep_number': 2004015,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_018': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (60000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13338.343198},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2005001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Rheobase",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Rheobase',
#    'sweep_number': 2005001,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_019': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (60000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13341.631399},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2006001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Rheobase",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Rheobase',
#    'sweep_number': 2006001,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_020': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (60000,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13344.9368},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2007001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Rheobase",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Rheobase',
#    'sweep_number': 2007001,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_021': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13348.258599},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008001,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_022': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13350.424598},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008002,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008002,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_023': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13352.610199},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008003,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008003,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_024': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13354.791799},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008004,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008004,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_025': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13356.978999},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008005,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008005,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_026': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13359.163999},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008006,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008006,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_027': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13361.346999},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008007,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008007,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_028': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13363.527999},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008008,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008008,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_029': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13365.715999},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008009,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008009,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_030': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13367.897199},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008010,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008010,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_031': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13370.079799},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008011,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008011,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_032': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13372.262799},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008012,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008012,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_033': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13374.448599},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008013,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008013,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
#        'neurodata_type': 'Device'}}}}},
#   'index_034': {'bias_current': {'attributes': {},
#     'data': -7.32491671929144e-12},
#    'bridge_balance': {'attributes': {}, 'data': 19999656.50140994},
#    'capacitance_compensation': {'attributes': {},
#     'data': 6.061365122968126e-12},
#    'data': {'attributes': {'conversion': 1.0, 'resolution': nan, 'unit': 'V'},
#     'data': <HDF5 dataset "data": shape (40400,), type "<f4">},
#    'gain': {'attributes': {}, 'data': 100000000.0},
#    'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#     'data': 13376.631799},
#    'comments': 'no comments',
#    'description': '{\n    "cycle_id": 2008014,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#    'help': 'Voltage recorded from cell during current-clamp recording',
#    'namespace': 'core',
#    'neurodata_type': 'CurrentClampSeries',
#    'stimulus_description': 'Short square',
#    'sweep_number': 2008014,
#    'electrode': {'builder': {'description': {'attributes': {},
#       'data': 'PLACEHOLDER'},
#      'help': 'Metadata about an intracellular electrode',
#      'namespace': 'core',
#      'neurodata_type': 'IntracellularElectrode',
#      'device': {'builder': {'help': 'A recording device e.g. amplifier',
#        'namespace': 'core',
# ...
#     'sweep_number': 2008029,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_050': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (40399,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#      'data': 13411.640799},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2008030,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Short square',
#     'sweep_number': 2008030,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_051': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (40399,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#      'data': 13413.824399},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2008031,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Short square',
#     'sweep_number': 2008031,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_052': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (40399,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 20000.0, 'unit': 'Seconds'},
#      'data': 13416.006999},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2008032,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Short square",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Short square',
#     'sweep_number': 2008032,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_053': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (155998,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 49999.99999999999,
#       'unit': 'Seconds'},
#      'data': 13421.600959},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2009001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Ramp",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Ramp',
#     'sweep_number': 2009001,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_054': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (1643998,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 199999.99999999997,
#       'unit': 'Seconds'},
#      'data': 13424.944279},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2010001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Capacitance",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Capacitance',
#     'sweep_number': 2010001,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_055': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (1643998,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 199999.99999999997,
#       'unit': 'Seconds'},
#      'data': 13433.399619},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2010002,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Capacitance",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Capacitance',
#     'sweep_number': 2010002,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_056': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (1643998,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 199999.99999999997,
#       'unit': 'Seconds'},
#      'data': 13441.822899},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2010003,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Capacitance",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Capacitance',
#     'sweep_number': 2010003,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_057': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (1643998,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 199999.99999999997,
#       'unit': 'Seconds'},
#      'data': 13450.309959},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2010004,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Capacitance",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Capacitance',
#     'sweep_number': 2010004,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_058': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (1643998,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 199999.99999999997,
#       'unit': 'Seconds'},
#      'data': 13458.73396},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2010005,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Capacitance",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Capacitance',
#     'sweep_number': 2010005,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_059': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (50997,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 49999.99999999999,
#       'unit': 'Seconds'},
#      'data': 13467.220999},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2011001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Chirp test",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Chirp test',
#     'sweep_number': 2011001,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_060': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (1999997,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 49999.99999999999,
#       'unit': 'Seconds'},
#      'data': 13468.624119},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2012001,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Chirp",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Chirp',
#     'sweep_number': 2012001,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_061': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (1999997,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 49999.99999999999,
#       'unit': 'Seconds'},
#      'data': 13508.981919},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2012002,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Chirp",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Chirp',
#     'sweep_number': 2012002,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}},
#    'index_062': {'data': {'attributes': {'conversion': 1e-12,
#       'resolution': nan,
#       'unit': 'A'},
#      'data': <HDF5 dataset "data": shape (1999997,), type "<f4">},
#     'gain': {'attributes': {}, 'data': 1.0},
#     'starting_time': {'attributes': {'rate': 49999.99999999999,
#       'unit': 'Seconds'},
#      'data': 13549.353719},
#     'comments': 'no comments',
#     'description': '{\n    "cycle_id": 2012003,\n    "file": "H19.28.012.11.05.dat",\n    "group_label": "PGS4_190418_701_A01",\n    "series_label": "Chirp",\n    "sweep_label": ""\n}',
#     'help': 'Stimulus current applied during current clamp recording',
#     'namespace': 'core',
#     'neurodata_type': 'CurrentClampStimulusSeries',
#     'stimulus_description': 'Chirp',
#     'sweep_number': 2012003,
#     'electrode': {'builder': {'description': {'attributes': {},
#        'data': 'PLACEHOLDER'},
#       'help': 'Metadata about an intracellular electrode',
#       'namespace': 'core',
#       'neurodata_type': 'IntracellularElectrode',
#       'device': {'builder': {'help': 'A recording device e.g. amplifier',
#         'namespace': 'core',
#         'neurodata_type': 'Device'}}}}}},
#   'templates': {}},
#  'file_create_date': {'attributes': {},
#   'data': array([b'2019-05-13T10:51:31.069049-07:00'], dtype=object)},
#  'identifier': {'attributes': {},
#   'data': '1ed51563e8f0218c0270ee9fb6c27b0b1558c4b821c10be2756797a697b35ff3'},
#  'session_description': {'attributes': {}, 'data': 'PLACEHOLDER'},
#  'session_start_time': {'attributes': {},
#   'data': '2019-04-18T03:41:56.136000-07:00'},
#  'timestamps_reference_time': {'attributes': {},
#   'data': '2019-04-18T03:41:56.136000-07:00'},
#  'help': 'an NWB:N file for storing cellular-based neurophysiology data',
#  'namespace': 'core',
#  'neurodata_type': 'NWBFile',
#  'nwb_version': '2.0b'}

# %%
# Plotting settings
show_bar_plot = False    # Change setting to plot distribution of object sizes in the HDF5 file
plot_single_file = True # Plot all files or a single example file

from utils.render import HierarchyDescription, NXGraphHierarchyDescription
import matplotlib.pyplot as plt
       
# Create the plots for all files
file_hierarchy = HierarchyDescription.from_hdf5(filename)
file_graph = NXGraphHierarchyDescription(file_hierarchy)
fig = file_graph.draw(show_plot=False,
                      figsize=(12,16),
                      label_offset=(0.0, 0.0065),
                      label_font_size=10)
print("fig = ", fig)
plot_title = filename + " \n " + "#Datasets=%i, #Attributes=%i, #Groups=%i, #Links=%i" % (len(file_hierarchy['datasets']), len(file_hierarchy['attributes']), len(file_hierarchy['groups']), len(file_hierarchy['links']))
plt.title(plot_title)
plt.show()
# Out:
# fig =  Figure(864x1152)

# %%
# An other way to read the NWB file
container = io2.read()
print("container = ", container)
# Out:
# container =
# root <class 'pynwb.file.NWBFile'>
# Fields:
#   acquisition: { index_000 <class 'pynwb.icephys.VoltageClampSeries'>,  index_001 <class 'pynwb.icephys.VoltageClampSeries'>,  index_002 <class 'pynwb.icephys.VoltageClampSeries'>,  index_003 <class 'pynwb.icephys.CurrentClampSeries'>,  index_004 <class 'pynwb.icephys.CurrentClampSeries'>,  index_005 <class 'pynwb.icephys.CurrentClampSeries'>,  index_006 <class 'pynwb.icephys.CurrentClampSeries'>,  index_007 <class 'pynwb.icephys.CurrentClampSeries'>,  index_008 <class 'pynwb.icephys.CurrentClampSeries'>,  index_009 <class 'pynwb.icephys.CurrentClampSeries'>,  index_010 <class 'pynwb.icephys.CurrentClampSeries'>,  index_011 <class 'pynwb.icephys.CurrentClampSeries'>,  index_012 <class 'pynwb.icephys.CurrentClampSeries'>,  index_013 <class 'pynwb.icephys.CurrentClampSeries'>,  index_014 <class 'pynwb.icephys.CurrentClampSeries'>,  index_015 <class 'pynwb.icephys.CurrentClampSeries'>,  index_016 <class 'pynwb.icephys.CurrentClampSeries'>,  index_017 <class 'pynwb.icephys.CurrentClampSeries'>,  index_018 <class 'pynwb.icephys.CurrentClampSeries'>,  index_019 <class 'pynwb.icephys.CurrentClampSeries'>,  index_020 <class 'pynwb.icephys.CurrentClampSeries'>,  index_021 <class 'pynwb.icephys.CurrentClampSeries'>,  index_022 <class 'pynwb.icephys.CurrentClampSeries'>,  index_023 <class 'pynwb.icephys.CurrentClampSeries'>,  index_024 <class 'pynwb.icephys.CurrentClampSeries'>,  index_025 <class 'pynwb.icephys.CurrentClampSeries'>,  index_026 <class 'pynwb.icephys.CurrentClampSeries'>,  index_027 <class 'pynwb.icephys.CurrentClampSeries'>,  index_028 <class 'pynwb.icephys.CurrentClampSeries'>,  index_029 <class 'pynwb.icephys.CurrentClampSeries'>,  index_030 <class 'pynwb.icephys.CurrentClampSeries'>,  index_031 <class 'pynwb.icephys.CurrentClampSeries'>,  index_032 <class 'pynwb.icephys.CurrentClampSeries'>,  index_033 <class 'pynwb.icephys.CurrentClampSeries'>,  index_034 <class 'pynwb.icephys.CurrentClampSeries'>,  index_035 <class 'pynwb.icephys.CurrentClampSeries'>,  index_036 <class 'pynwb.icephys.CurrentClampSeries'>,  index_037 <class 'pynwb.icephys.CurrentClampSeries'>,  index_038 <class 'pynwb.icephys.CurrentClampSeries'>,  index_039 <class 'pynwb.icephys.CurrentClampSeries'>,  index_040 <class 'pynwb.icephys.CurrentClampSeries'>,  index_041 <class 'pynwb.icephys.CurrentClampSeries'>,  index_042 <class 'pynwb.icephys.CurrentClampSeries'>,  index_043 <class 'pynwb.icephys.CurrentClampSeries'>,  index_044 <class 'pynwb.icephys.CurrentClampSeries'>,  index_045 <class 'pynwb.icephys.CurrentClampSeries'>,  index_046 <class 'pynwb.icephys.CurrentClampSeries'>,  index_047 <class 'pynwb.icephys.CurrentClampSeries'>,  index_048 <class 'pynwb.icephys.CurrentClampSeries'>,  index_049 <class 'pynwb.icephys.CurrentClampSeries'>,  index_050 <class 'pynwb.icephys.CurrentClampSeries'>,  index_051 <class 'pynwb.icephys.CurrentClampSeries'>,  index_052 <class 'pynwb.icephys.CurrentClampSeries'>,  index_053 <class 'pynwb.icephys.CurrentClampSeries'>,  index_054 <class 'pynwb.icephys.CurrentClampSeries'>,  index_055 <class 'pynwb.icephys.CurrentClampSeries'>,  index_056 <class 'pynwb.icephys.CurrentClampSeries'>,  index_057 <class 'pynwb.icephys.CurrentClampSeries'>,  index_058 <class 'pynwb.icephys.CurrentClampSeries'>,  index_059 <class 'pynwb.icephys.CurrentClampSeries'>,  index_060 <class 'pynwb.icephys.CurrentClampSeries'>,  index_061 <class 'pynwb.icephys.CurrentClampSeries'>,  index_062 <class 'pynwb.icephys.CurrentClampSeries'> }
#   analysis: { }
#   devices: { Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'> }
#   electrode_groups: { }
#   epoch_tags: {}
#   experiment_description: PatchMaster v2x90.3, 19-Mar-2018
#   ic_electrodes: { Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'> }
#   imaging_planes: { }
#   lab_meta_data: { }
#   modules: { }
#   ogen_sites: { }
#   session_id: PLACEHOLDER
#   source_script: {
#     "git_revision": "() ",
#     "package_version": "0.16.2",
#     "repo": "https://github.com/AllenInstitute/ipfx"
# }
#   source_script_file_name: run_x_to_nwb_conversion.py
#   stimulus: { index_000 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,  index_001 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,  index_002 <class 'pynwb.icephys.VoltageClampStimulusSeries'>,  index_003 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_004 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_005 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_006 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_007 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_008 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_009 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_010 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_011 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_012 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_013 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_014 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_015 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_016 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_017 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_018 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_019 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_020 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_021 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_022 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_023 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_024 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_025 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_026 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_027 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_028 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_029 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_030 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_031 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_032 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_033 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_034 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_035 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_036 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_037 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_038 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_039 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_040 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_041 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_042 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_043 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_044 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_045 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_046 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_047 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_048 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_049 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_050 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_051 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_052 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_053 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_054 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_055 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_056 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_057 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_058 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_059 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_060 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_061 <class 'pynwb.icephys.CurrentClampStimulusSeries'>,  index_062 <class 'pynwb.icephys.CurrentClampStimulusSeries'> }
#   stimulus_template: { }
#   sweep_table: sweep_table <class 'pynwb.icephys.SweepTable'>
#   time_intervals: { }

# %%
# All fields in each part

print("container.fields = ", container.fields)
# Out:
# container.fields =  {'acquisition': {'index_000':
# index_000 <class 'pynwb.icephys.VoltageClampSeries'>
# Fields:
#   capacitance_fast: 0.0
#   capacitance_slow: nan
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (70000,), type "<f4">
#   description: {
#     "cycle_id": 2001001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "extpinbath",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 5000000.0
#   num_samples: 70000
#   rate: 199999.99999999997
#   resistance_comp_bandwidth: nan
#   resistance_comp_correction: nan
#   resistance_comp_prediction: nan
#   resolution: nan
#   starting_time: 13008.059839
#   starting_time_unit: Seconds
#   stimulus_description: extpinbath
#   sweep_number: 2001001
#   unit: A
#   whole_cell_capacitance_comp: nan
#   whole_cell_series_resistance_comp: nan
# , 'index_001':
# index_001 <class 'pynwb.icephys.VoltageClampSeries'>
# Fields:
#   capacitance_fast: 6.063405827748043e-12
#   capacitance_slow: nan
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (70000,), type "<f4">
#   description: {
#     "cycle_id": 2002001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "extpciiatt",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 50000000.0
#   num_samples: 70000
#   rate: 199999.99999999997
#   resistance_comp_bandwidth: nan
#   resistance_comp_correction: nan
#   resistance_comp_prediction: nan
#   resolution: nan
#   starting_time: 13251.517779
#   starting_time_unit: Seconds
#   stimulus_description: extpciiatt
#   sweep_number: 2002001
#   unit: A
#   whole_cell_capacitance_comp: nan
#   whole_cell_series_resistance_comp: nan
# , 'index_002':
# index_002 <class 'pynwb.icephys.VoltageClampSeries'>
# Fields:
#   capacitance_fast: 6.063405827748043e-12
#   capacitance_slow: nan
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (70000,), type "<f4">
#   description: {
#     "cycle_id": 2003001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "extpbreakn",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 70000
#   rate: 199999.99999999997
#   resistance_comp_bandwidth: nan
#   resistance_comp_correction: nan
#   resistance_comp_prediction: nan
#   resolution: nan
#   starting_time: 13287.819879
#   starting_time_unit: Seconds
#   stimulus_description: extpbreakn
#   sweep_number: 2003001
#   unit: A
#   whole_cell_capacitance_comp: nan
#   whole_cell_series_resistance_comp: nan
# , 'index_003':
# index_003 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13288.833239
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004001
#   unit: V
# , 'index_004':
# index_004 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13292.12488
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004002
#   unit: V
# , 'index_005':
# index_005 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004003,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13295.4318
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004003
#   unit: V
# , 'index_006':
# index_006 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004004,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13298.739679
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004004
#   unit: V
# , 'index_007':
# index_007 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004005,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13302.046879
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004005
#   unit: V
# , 'index_008':
# index_008 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004006,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13305.35316
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004006
#   unit: V
# , 'index_009':
# index_009 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004007,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13308.661599
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004007
#   unit: V
# , 'index_010':
# index_010 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004008,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13311.96852
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004008
#   unit: V
# , 'index_011':
# index_011 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004009,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13315.275799
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004009
#   unit: V
# , 'index_012':
# index_012 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004010,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13318.58284
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004010
#   unit: V
# , 'index_013':
# index_013 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004011,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13321.889359
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004011
#   unit: V
# , 'index_014':
# index_014 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004012,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13325.197719
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004012
#   unit: V
# , 'index_015':
# index_015 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004013,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13328.566759
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004013
#   unit: V
# , 'index_016':
# index_016 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004014,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13331.811558
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004014
#   unit: V
# , 'index_017':
# index_017 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004015,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13335.05688
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004015
#   unit: V
# , 'index_018':
# index_018 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (60000,), type "<f4">
#   description: {
#     "cycle_id": 2005001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Rheobase",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 60000
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13338.343198
#   starting_time_unit: Seconds
#   stimulus_description: Rheobase
#   sweep_number: 2005001
#   unit: V
# , 'index_019':
# index_019 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (60000,), type "<f4">
#   description: {
#     "cycle_id": 2006001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Rheobase",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 60000
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13341.631399
#   starting_time_unit: Seconds
#   stimulus_description: Rheobase
#   sweep_number: 2006001
#   unit: V
# , 'index_020':
# index_020 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (60000,), type "<f4">
#   description: {
#     "cycle_id": 2007001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Rheobase",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 60000
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13344.9368
#   starting_time_unit: Seconds
#   stimulus_description: Rheobase
#   sweep_number: 2007001
#   unit: V
# , 'index_021':
# index_021 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13348.258599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008001
#   unit: V
# , 'index_022':
# index_022 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13350.424598
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008002
#   unit: V
# , 'index_023':
# index_023 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008003,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13352.610199
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008003
#   unit: V
# , 'index_024':
# index_024 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008004,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13354.791799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008004
#   unit: V
# , 'index_025':
# index_025 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008005,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13356.978999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008005
#   unit: V
# , 'index_026':
# index_026 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008006,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13359.163999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008006
#   unit: V
# , 'index_027':
# index_027 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008007,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13361.346999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008007
#   unit: V
# , 'index_028':
# index_028 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008008,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13363.527999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008008
#   unit: V
# , 'index_029':
# index_029 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008009,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13365.715999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008009
#   unit: V
# , 'index_030':
# index_030 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008010,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13367.897199
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008010
#   unit: V
# , 'index_031':
# index_031 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008011,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13370.079799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008011
#   unit: V
# , 'index_032':
# index_032 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008012,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13372.262799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008012
#   unit: V
# , 'index_033':
# index_033 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008013,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13374.448599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008013
#   unit: V
# , 'index_034':
# index_034 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008014,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13376.631799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008014
#   unit: V
# , 'index_035':
# index_035 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008015,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13378.821399
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008015
#   unit: V
# , 'index_036':
# index_036 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008016,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13381.0048
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008016
#   unit: V
# , 'index_037':
# index_037 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008017,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13383.188199
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008017
#   unit: V
# , 'index_038':
# index_038 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008018,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13385.372199
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008018
#   unit: V
# , 'index_039':
# index_039 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008019,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13387.552799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008019
#   unit: V
# , 'index_040':
# index_040 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008020,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13389.736599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008020
#   unit: V
# , 'index_041':
# index_041 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008021,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13391.921799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008021
#   unit: V
# , 'index_042':
# index_042 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008022,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13394.102999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008022
#   unit: V
# , 'index_043':
# index_043 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008023,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13396.288999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008023
#   unit: V
# , 'index_044':
# index_044 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008024,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13398.475799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008024
#   unit: V
# , 'index_045':
# index_045 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008025,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13400.7178
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008025
#   unit: V
# , 'index_046':
# index_046 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008026,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13402.904599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008026
#   unit: V
# , 'index_047':
# index_047 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008027,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13405.087999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008027
#   unit: V
# , 'index_048':
# index_048 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008028,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13407.274399
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008028
#   unit: V
# , 'index_049':
# index_049 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008029,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13409.455999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008029
#   unit: V
# , 'index_050':
# index_050 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008030,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13411.640799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008030
#   unit: V
# , 'index_051':
# index_051 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008031,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13413.824399
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008031
#   unit: V
# , 'index_052':
# index_052 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008032,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13416.006999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008032
#   unit: V
# , 'index_053':
# index_053 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (156000,), type "<f4">
#   description: {
#     "cycle_id": 2009001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Ramp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 156000
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13421.600959
#   starting_time_unit: Seconds
#   stimulus_description: Ramp
#   sweep_number: 2009001
#   unit: V
# , 'index_054':
# index_054 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13424.944279
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010001
#   unit: V
# , 'index_055':
# index_055 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13433.399619
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010002
#   unit: V
# , 'index_056':
# index_056 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010003,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13441.822899
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010003
#   unit: V
# , 'index_057':
# index_057 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010004,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13450.309959
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010004
#   unit: V
# , 'index_058':
# index_058 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010005,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13458.73396
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010005
#   unit: V
# , 'index_059':
# index_059 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (51000,), type "<f4">
#   description: {
#     "cycle_id": 2011001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp test",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 51000
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13467.220999
#   starting_time_unit: Seconds
#   stimulus_description: Chirp test
#   sweep_number: 2011001
#   unit: V
# , 'index_060':
# index_060 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (2000000,), type "<f4">
#   description: {
#     "cycle_id": 2012001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 2000000
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13468.624119
#   starting_time_unit: Seconds
#   stimulus_description: Chirp
#   sweep_number: 2012001
#   unit: V
# , 'index_061':
# index_061 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (2000000,), type "<f4">
#   description: {
#     "cycle_id": 2012002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 2000000
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13508.981919
#   starting_time_unit: Seconds
#   stimulus_description: Chirp
#   sweep_number: 2012002
#   unit: V
# , 'index_062':
# index_062 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (2000000,), type "<f4">
#   description: {
#     "cycle_id": 2012003,
# ...
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008020,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13389.736599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008020
#   unit: A
# , 'index_041':
# index_041 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008021,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13391.921799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008021
#   unit: A
# , 'index_042':
# index_042 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008022,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13394.102999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008022
#   unit: A
# , 'index_043':
# index_043 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008023,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13396.288999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008023
#   unit: A
# , 'index_044':
# index_044 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008024,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13398.475799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008024
#   unit: A
# , 'index_045':
# index_045 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008025,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13400.7178
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008025
#   unit: A
# , 'index_046':
# index_046 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008026,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13402.904599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008026
#   unit: A
# , 'index_047':
# index_047 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008027,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13405.087999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008027
#   unit: A
# , 'index_048':
# index_048 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008028,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13407.274399
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008028
#   unit: A
# , 'index_049':
# index_049 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008029,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13409.455999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008029
#   unit: A
# , 'index_050':
# index_050 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008030,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13411.640799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008030
#   unit: A
# , 'index_051':
# index_051 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008031,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13413.824399
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008031
#   unit: A
# , 'index_052':
# index_052 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (40399,), type "<f4">
#   description: {
#     "cycle_id": 2008032,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 40399
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13416.006999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008032
#   unit: A
# , 'index_053':
# index_053 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (155998,), type "<f4">
#   description: {
#     "cycle_id": 2009001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Ramp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 155998
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13421.600959
#   starting_time_unit: Seconds
#   stimulus_description: Ramp
#   sweep_number: 2009001
#   unit: A
# , 'index_054':
# index_054 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#   description: {
#     "cycle_id": 2010001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 1643998
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13424.944279
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010001
#   unit: A
# , 'index_055':
# index_055 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#   description: {
#     "cycle_id": 2010002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 1643998
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13433.399619
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010002
#   unit: A
# , 'index_056':
# index_056 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#   description: {
#     "cycle_id": 2010003,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 1643998
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13441.822899
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010003
#   unit: A
# , 'index_057':
# index_057 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#   description: {
#     "cycle_id": 2010004,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 1643998
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13450.309959
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010004
#   unit: A
# , 'index_058':
# index_058 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#   description: {
#     "cycle_id": 2010005,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 1643998
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13458.73396
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010005
#   unit: A
# , 'index_059':
# index_059 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (50997,), type "<f4">
#   description: {
#     "cycle_id": 2011001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp test",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 50997
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13467.220999
#   starting_time_unit: Seconds
#   stimulus_description: Chirp test
#   sweep_number: 2011001
#   unit: A
# , 'index_060':
# index_060 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (1999997,), type "<f4">
#   description: {
#     "cycle_id": 2012001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 1999997
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13468.624119
#   starting_time_unit: Seconds
#   stimulus_description: Chirp
#   sweep_number: 2012001
#   unit: A
# , 'index_061':
# index_061 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (1999997,), type "<f4">
#   description: {
#     "cycle_id": 2012002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 1999997
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13508.981919
#   starting_time_unit: Seconds
#   stimulus_description: Chirp
#   sweep_number: 2012002
#   unit: A
# , 'index_062':
# index_062 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
# Fields:
#   comments: no comments
#   conversion: 1e-12
#   data: <HDF5 dataset "data": shape (1999997,), type "<f4">
#   description: {
#     "cycle_id": 2012003,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 1.0
#   num_samples: 1999997
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13549.353719
#   starting_time_unit: Seconds
#   stimulus_description: Chirp
#   sweep_number: 2012003
#   unit: A
# }, 'stimulus_template': {}, 'modules': {}, 'devices': {'Unknown (value: 5)-4-1 with Unknown (value: 3)':
# Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
# Fields:
# }, 'electrode_groups': {}, 'imaging_planes': {}, 'ic_electrodes': {'Electrode 0':
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
# }, 'ogen_sites': {}, 'time_intervals': {}, 'lab_meta_data': {}, 'epoch_tags': set(), 'sweep_table':
# sweep_table <class 'pynwb.icephys.SweepTable'>
# Fields:
#   colnames: ('series', 'sweep_number')
#   columns: [
# series_index <class 'pynwb.core.VectorIndex'>
# Fields:
#   target: series <class 'pynwb.core.VectorData'>
# ,
# series <class 'pynwb.core.VectorData'>
# Fields:
#   description: PatchClampSeries with the same sweep number
# ,
# sweep_number <class 'pynwb.core.VectorData'>
# Fields:
#   description: Sweep number of the entries in that row
# ]
#   description: A sweep table groups different PatchClampSeries together.
#   id: id <class 'pynwb.core.ElementIdentifiers'>
# , 'experiment_description': 'PatchMaster v2x90.3, 19-Mar-2018', 'session_id': 'PLACEHOLDER', 'source_script': '{\n    "git_revision": "() ",\n    "package_version": "0.16.2",\n    "repo": "https://github.com/AllenInstitute/ipfx"\n}', 'source_script_file_name': 'run_x_to_nwb_conversion.py'}

# %%
# Fields in acquisition

acquisition = container.acquisition
print("acquisition = ", acquisition)
# Out:
# acquisition =  {'index_000':
# index_000 <class 'pynwb.icephys.VoltageClampSeries'>
# Fields:
#   capacitance_fast: 0.0
#   capacitance_slow: nan
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (70000,), type "<f4">
#   description: {
#     "cycle_id": 2001001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "extpinbath",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 5000000.0
#   num_samples: 70000
#   rate: 199999.99999999997
#   resistance_comp_bandwidth: nan
#   resistance_comp_correction: nan
#   resistance_comp_prediction: nan
#   resolution: nan
#   starting_time: 13008.059839
#   starting_time_unit: Seconds
#   stimulus_description: extpinbath
#   sweep_number: 2001001
#   unit: A
#   whole_cell_capacitance_comp: nan
#   whole_cell_series_resistance_comp: nan
# , 'index_001':
# index_001 <class 'pynwb.icephys.VoltageClampSeries'>
# Fields:
#   capacitance_fast: 6.063405827748043e-12
#   capacitance_slow: nan
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (70000,), type "<f4">
#   description: {
#     "cycle_id": 2002001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "extpciiatt",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 50000000.0
#   num_samples: 70000
#   rate: 199999.99999999997
#   resistance_comp_bandwidth: nan
#   resistance_comp_correction: nan
#   resistance_comp_prediction: nan
#   resolution: nan
#   starting_time: 13251.517779
#   starting_time_unit: Seconds
#   stimulus_description: extpciiatt
#   sweep_number: 2002001
#   unit: A
#   whole_cell_capacitance_comp: nan
#   whole_cell_series_resistance_comp: nan
# , 'index_002':
# index_002 <class 'pynwb.icephys.VoltageClampSeries'>
# Fields:
#   capacitance_fast: 6.063405827748043e-12
#   capacitance_slow: nan
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (70000,), type "<f4">
#   description: {
#     "cycle_id": 2003001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "extpbreakn",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 70000
#   rate: 199999.99999999997
#   resistance_comp_bandwidth: nan
#   resistance_comp_correction: nan
#   resistance_comp_prediction: nan
#   resolution: nan
#   starting_time: 13287.819879
#   starting_time_unit: Seconds
#   stimulus_description: extpbreakn
#   sweep_number: 2003001
#   unit: A
#   whole_cell_capacitance_comp: nan
#   whole_cell_series_resistance_comp: nan
# , 'index_003':
# index_003 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13288.833239
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004001
#   unit: V
# , 'index_004':
# index_004 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13292.12488
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004002
#   unit: V
# , 'index_005':
# index_005 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004003,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13295.4318
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004003
#   unit: V
# , 'index_006':
# index_006 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004004,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13298.739679
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004004
#   unit: V
# , 'index_007':
# index_007 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004005,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13302.046879
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004005
#   unit: V
# , 'index_008':
# index_008 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004006,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13305.35316
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004006
#   unit: V
# , 'index_009':
# index_009 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004007,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13308.661599
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004007
#   unit: V
# , 'index_010':
# index_010 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004008,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13311.96852
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004008
#   unit: V
# , 'index_011':
# index_011 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004009,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13315.275799
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004009
#   unit: V
# , 'index_012':
# index_012 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004010,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13318.58284
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004010
#   unit: V
# , 'index_013':
# index_013 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004011,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13321.889359
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004011
#   unit: V
# , 'index_014':
# index_014 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004012,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13325.197719
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004012
#   unit: V
# , 'index_015':
# index_015 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004013,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13328.566759
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004013
#   unit: V
# , 'index_016':
# index_016 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004014,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13331.811558
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004014
#   unit: V
# , 'index_017':
# index_017 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (300000,), type "<f4">
#   description: {
#     "cycle_id": 2004015,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Long square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 300000
#   rate: 99999.99999999999
#   resolution: nan
#   starting_time: 13335.05688
#   starting_time_unit: Seconds
#   stimulus_description: Long square
#   sweep_number: 2004015
#   unit: V
# , 'index_018':
# index_018 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (60000,), type "<f4">
#   description: {
#     "cycle_id": 2005001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Rheobase",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 60000
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13338.343198
#   starting_time_unit: Seconds
#   stimulus_description: Rheobase
#   sweep_number: 2005001
#   unit: V
# , 'index_019':
# index_019 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (60000,), type "<f4">
#   description: {
#     "cycle_id": 2006001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Rheobase",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 60000
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13341.631399
#   starting_time_unit: Seconds
#   stimulus_description: Rheobase
#   sweep_number: 2006001
#   unit: V
# , 'index_020':
# index_020 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (60000,), type "<f4">
#   description: {
#     "cycle_id": 2007001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Rheobase",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 60000
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13344.9368
#   starting_time_unit: Seconds
#   stimulus_description: Rheobase
#   sweep_number: 2007001
#   unit: V
# , 'index_021':
# index_021 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13348.258599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008001
#   unit: V
# , 'index_022':
# index_022 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13350.424598
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008002
#   unit: V
# , 'index_023':
# index_023 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008003,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13352.610199
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008003
#   unit: V
# , 'index_024':
# index_024 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008004,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13354.791799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008004
#   unit: V
# , 'index_025':
# index_025 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008005,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13356.978999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008005
#   unit: V
# , 'index_026':
# index_026 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008006,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13359.163999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008006
#   unit: V
# , 'index_027':
# index_027 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008007,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13361.346999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008007
#   unit: V
# , 'index_028':
# index_028 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008008,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13363.527999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008008
#   unit: V
# , 'index_029':
# index_029 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008009,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13365.715999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008009
#   unit: V
# , 'index_030':
# index_030 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008010,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13367.897199
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008010
#   unit: V
# , 'index_031':
# index_031 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008011,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13370.079799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008011
#   unit: V
# , 'index_032':
# index_032 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008012,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13372.262799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008012
#   unit: V
# , 'index_033':
# index_033 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008013,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13374.448599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008013
#   unit: V
# , 'index_034':
# index_034 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008014,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13376.631799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008014
#   unit: V
# , 'index_035':
# index_035 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008015,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13378.821399
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008015
#   unit: V
# , 'index_036':
# index_036 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008016,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13381.0048
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008016
#   unit: V
# , 'index_037':
# index_037 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008017,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13383.188199
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008017
#   unit: V
# , 'index_038':
# index_038 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008018,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13385.372199
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008018
#   unit: V
# , 'index_039':
# index_039 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008019,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13387.552799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008019
#   unit: V
# , 'index_040':
# index_040 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008020,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13389.736599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008020
#   unit: V
# , 'index_041':
# index_041 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008021,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13391.921799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008021
#   unit: V
# , 'index_042':
# index_042 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008022,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13394.102999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008022
#   unit: V
# , 'index_043':
# index_043 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008023,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13396.288999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008023
#   unit: V
# , 'index_044':
# index_044 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008024,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13398.475799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008024
#   unit: V
# , 'index_045':
# index_045 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008025,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13400.7178
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008025
#   unit: V
# , 'index_046':
# index_046 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008026,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13402.904599
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008026
#   unit: V
# , 'index_047':
# index_047 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008027,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13405.087999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008027
#   unit: V
# , 'index_048':
# index_048 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008028,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13407.274399
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008028
#   unit: V
# , 'index_049':
# index_049 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008029,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13409.455999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008029
#   unit: V
# , 'index_050':
# index_050 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008030,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13411.640799
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008030
#   unit: V
# , 'index_051':
# index_051 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008031,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13413.824399
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008031
#   unit: V
# , 'index_052':
# index_052 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (40400,), type "<f4">
#   description: {
#     "cycle_id": 2008032,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Short square",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 40400
#   rate: 20000.0
#   resolution: nan
#   starting_time: 13416.006999
#   starting_time_unit: Seconds
#   stimulus_description: Short square
#   sweep_number: 2008032
#   unit: V
# , 'index_053':
# index_053 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (156000,), type "<f4">
#   description: {
#     "cycle_id": 2009001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Ramp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 156000
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13421.600959
#   starting_time_unit: Seconds
#   stimulus_description: Ramp
#   sweep_number: 2009001
#   unit: V
# , 'index_054':
# index_054 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13424.944279
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010001
#   unit: V
# , 'index_055':
# index_055 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13433.399619
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010002
#   unit: V
# , 'index_056':
# index_056 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010003,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13441.822899
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010003
#   unit: V
# , 'index_057':
# index_057 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010004,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13450.309959
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010004
#   unit: V
# , 'index_058':
# index_058 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1644000,), type "<f4">
#   description: {
#     "cycle_id": 2010005,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Capacitance",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 1644000
#   rate: 199999.99999999997
#   resolution: nan
#   starting_time: 13458.73396
#   starting_time_unit: Seconds
#   stimulus_description: Capacitance
#   sweep_number: 2010005
#   unit: V
# , 'index_059':
# index_059 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (51000,), type "<f4">
#   description: {
#     "cycle_id": 2011001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp test",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 51000
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13467.220999
#   starting_time_unit: Seconds
#   stimulus_description: Chirp test
#   sweep_number: 2011001
#   unit: V
# , 'index_060':
# index_060 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (2000000,), type "<f4">
#   description: {
#     "cycle_id": 2012001,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 2000000
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13468.624119
#   starting_time_unit: Seconds
#   stimulus_description: Chirp
#   sweep_number: 2012001
#   unit: V
# , 'index_061':
# index_061 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (2000000,), type "<f4">
#   description: {
#     "cycle_id": 2012002,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 2000000
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13508.981919
#   starting_time_unit: Seconds
#   stimulus_description: Chirp
#   sweep_number: 2012002
#   unit: V
# , 'index_062':
# index_062 <class 'pynwb.icephys.CurrentClampSeries'>
# Fields:
#   bias_current: -7.32491671929144e-12
#   bridge_balance: 19999656.50140994
#   capacitance_compensation: 6.061365122968126e-12
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (2000000,), type "<f4">
#   description: {
#     "cycle_id": 2012003,
#     "file": "H19.28.012.11.05.dat",
#     "group_label": "PGS4_190418_701_A01",
#     "series_label": "Chirp",
#     "sweep_label": ""
# }
#   electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#   gain: 100000000.0
#   num_samples: 2000000
#   rate: 49999.99999999999
#   resolution: nan
#   starting_time: 13549.353719
#   starting_time_unit: Seconds
#   stimulus_description: Chirp
#   sweep_number: 2012003
#   unit: V
# }

# %%
for i in acquisition:
    print("i = ", i) # index_000
#    print(container.get_acquisition(i).description)
    print("container.get_acquisition(i).electrode = ", container.get_acquisition(i).electrode)    
    print("container.get_acquisition(i).gain = ", container.get_acquisition(i).gain)
# Out:
# i =  index_000
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  5000000.0
# i =  index_001
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  50000000.0
# i =  index_002
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_003
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_004
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_005
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_006
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_007
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_008
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_009
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_010
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_011
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_012
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_013
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_014
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_015
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_016
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_017
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_018
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_019
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_020
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_021
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_022
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_023
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_024
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_025
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_026
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_027
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_028
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_029
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_030
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_031
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_032
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_033
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_034
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_035
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_036
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_037
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_038
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_039
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_040
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_041
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_042
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_043
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_044
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_045
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_046
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_047
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_048
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_049
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_050
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_051
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_052
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_053
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_054
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_055
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_056
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_057
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_058
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_059
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_060
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_061
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0
# i =  index_062
# container.get_acquisition(i).electrode =
# Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
# Fields:
#   description: PLACEHOLDER
#   device: Unknown (value: 5)-4-1 with Unknown (value: 3) <class 'pynwb.device.Device'>
#
# container.get_acquisition(i).gain =  100000000.0

# %%
# Stimulus

container.stimulus
# Out:
# {'index_000':
#  index_000 <class 'pynwb.icephys.VoltageClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 0.001
#    data: <HDF5 dataset "data": shape (69995,), type "<f4">
#    description: {
#      "cycle_id": 2001001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "extpinbath",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 69995
#    rate: 199999.99999999997
#    resolution: nan
#    starting_time: 13008.059839
#    starting_time_unit: Seconds
#    stimulus_description: extpinbath
#    sweep_number: 2001001
#    unit: V, 'index_001':
#  index_001 <class 'pynwb.icephys.VoltageClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 0.001
#    data: <HDF5 dataset "data": shape (69995,), type "<f4">
#    description: {
#      "cycle_id": 2002001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "extpciiatt",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 69995
#    rate: 199999.99999999997
#    resolution: nan
#    starting_time: 13251.517779
#    starting_time_unit: Seconds
#    stimulus_description: extpciiatt
#    sweep_number: 2002001
#    unit: V, 'index_002':
#  index_002 <class 'pynwb.icephys.VoltageClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 0.001
#    data: <HDF5 dataset "data": shape (69995,), type "<f4">
#    description: {
#      "cycle_id": 2003001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "extpbreakn",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 69995
#    rate: 199999.99999999997
#    resolution: nan
#    starting_time: 13287.819879
#    starting_time_unit: Seconds
#    stimulus_description: extpbreakn
#    sweep_number: 2003001
#    unit: V, 'index_003':
#  index_003 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13288.833239
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004001
#    unit: A, 'index_004':
#  index_004 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004002,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13292.12488
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004002
#    unit: A, 'index_005':
#  index_005 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004003,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13295.4318
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004003
#    unit: A, 'index_006':
#  index_006 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004004,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13298.739679
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004004
#    unit: A, 'index_007':
#  index_007 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004005,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13302.046879
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004005
#    unit: A, 'index_008':
#  index_008 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004006,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13305.35316
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004006
#    unit: A, 'index_009':
#  index_009 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004007,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13308.661599
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004007
#    unit: A, 'index_010':
#  index_010 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004008,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13311.96852
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004008
#    unit: A, 'index_011':
#  index_011 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004009,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13315.275799
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004009
#    unit: A, 'index_012':
#  index_012 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004010,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13318.58284
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004010
#    unit: A, 'index_013':
#  index_013 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004011,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13321.889359
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004011
#    unit: A, 'index_014':
#  index_014 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004012,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13325.197719
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004012
#    unit: A, 'index_015':
#  index_015 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004013,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13328.566759
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004013
#    unit: A, 'index_016':
#  index_016 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004014,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13331.811558
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004014
#    unit: A, 'index_017':
#  index_017 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (299996,), type "<f4">
#    description: {
#      "cycle_id": 2004015,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Long square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 299996
#    rate: 99999.99999999999
#    resolution: nan
#    starting_time: 13335.05688
#    starting_time_unit: Seconds
#    stimulus_description: Long square
#    sweep_number: 2004015
#    unit: A, 'index_018':
#  index_018 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (60000,), type "<f4">
#    description: {
#      "cycle_id": 2005001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Rheobase",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 60000
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13338.343198
#    starting_time_unit: Seconds
#    stimulus_description: Rheobase
#    sweep_number: 2005001
#    unit: A, 'index_019':
#  index_019 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (60000,), type "<f4">
#    description: {
#      "cycle_id": 2006001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Rheobase",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 60000
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13341.631399
#    starting_time_unit: Seconds
#    stimulus_description: Rheobase
#    sweep_number: 2006001
#    unit: A, 'index_020':
#  index_020 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (60000,), type "<f4">
#    description: {
#      "cycle_id": 2007001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Rheobase",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 60000
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13344.9368
#    starting_time_unit: Seconds
#    stimulus_description: Rheobase
#    sweep_number: 2007001
#    unit: A, 'index_021':
#  index_021 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13348.258599
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008001
#    unit: A, 'index_022':
#  index_022 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008002,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13350.424598
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008002
#    unit: A, 'index_023':
#  index_023 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008003,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13352.610199
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008003
#    unit: A, 'index_024':
#  index_024 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008004,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13354.791799
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008004
#    unit: A, 'index_025':
#  index_025 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008005,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13356.978999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008005
#    unit: A, 'index_026':
#  index_026 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008006,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13359.163999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008006
#    unit: A, 'index_027':
#  index_027 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008007,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13361.346999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008007
#    unit: A, 'index_028':
#  index_028 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008008,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13363.527999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008008
#    unit: A, 'index_029':
#  index_029 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008009,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13365.715999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008009
#    unit: A, 'index_030':
#  index_030 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008010,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13367.897199
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008010
#    unit: A, 'index_031':
#  index_031 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008011,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13370.079799
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008011
#    unit: A, 'index_032':
#  index_032 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008012,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13372.262799
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008012
#    unit: A, 'index_033':
#  index_033 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008013,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13374.448599
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008013
#    unit: A, 'index_034':
#  index_034 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008014,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13376.631799
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008014
#    unit: A, 'index_035':
#  index_035 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008015,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13378.821399
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008015
#    unit: A, 'index_036':
#  index_036 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008016,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13381.0048
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008016
#    unit: A, 'index_037':
#  index_037 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008017,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13383.188199
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008017
#    unit: A, 'index_038':
#  index_038 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008018,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13385.372199
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008018
#    unit: A, 'index_039':
#  index_039 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008019,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13387.552799
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008019
#    unit: A, 'index_040':
#  index_040 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008020,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13389.736599
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008020
#    unit: A, 'index_041':
#  index_041 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008021,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13391.921799
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008021
#    unit: A, 'index_042':
#  index_042 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008022,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13394.102999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008022
#    unit: A, 'index_043':
#  index_043 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008023,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13396.288999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008023
#    unit: A, 'index_044':
#  index_044 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008024,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13398.475799
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008024
#    unit: A, 'index_045':
#  index_045 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008025,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13400.7178
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008025
#    unit: A, 'index_046':
#  index_046 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008026,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13402.904599
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008026
#    unit: A, 'index_047':
#  index_047 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008027,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13405.087999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008027
#    unit: A, 'index_048':
#  index_048 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008028,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13407.274399
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008028
#    unit: A, 'index_049':
#  index_049 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008029,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13409.455999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008029
#    unit: A, 'index_050':
#  index_050 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008030,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13411.640799
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008030
#    unit: A, 'index_051':
#  index_051 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008031,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13413.824399
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008031
#    unit: A, 'index_052':
#  index_052 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (40399,), type "<f4">
#    description: {
#      "cycle_id": 2008032,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Short square",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 40399
#    rate: 20000.0
#    resolution: nan
#    starting_time: 13416.006999
#    starting_time_unit: Seconds
#    stimulus_description: Short square
#    sweep_number: 2008032
#    unit: A, 'index_053':
#  index_053 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (155998,), type "<f4">
#    description: {
#      "cycle_id": 2009001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Ramp",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 155998
#    rate: 49999.99999999999
#    resolution: nan
#    starting_time: 13421.600959
#    starting_time_unit: Seconds
#    stimulus_description: Ramp
#    sweep_number: 2009001
#    unit: A, 'index_054':
#  index_054 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#    description: {
#      "cycle_id": 2010001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Capacitance",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 1643998
#    rate: 199999.99999999997
#    resolution: nan
#    starting_time: 13424.944279
#    starting_time_unit: Seconds
#    stimulus_description: Capacitance
#    sweep_number: 2010001
#    unit: A, 'index_055':
#  index_055 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#    description: {
#      "cycle_id": 2010002,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Capacitance",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 1643998
#    rate: 199999.99999999997
#    resolution: nan
#    starting_time: 13433.399619
#    starting_time_unit: Seconds
#    stimulus_description: Capacitance
#    sweep_number: 2010002
#    unit: A, 'index_056':
#  index_056 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#    description: {
#      "cycle_id": 2010003,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Capacitance",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 1643998
#    rate: 199999.99999999997
#    resolution: nan
#    starting_time: 13441.822899
#    starting_time_unit: Seconds
#    stimulus_description: Capacitance
#    sweep_number: 2010003
#    unit: A, 'index_057':
#  index_057 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#    description: {
#      "cycle_id": 2010004,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Capacitance",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 1643998
#    rate: 199999.99999999997
#    resolution: nan
#    starting_time: 13450.309959
#    starting_time_unit: Seconds
#    stimulus_description: Capacitance
#    sweep_number: 2010004
#    unit: A, 'index_058':
#  index_058 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (1643998,), type "<f4">
#    description: {
#      "cycle_id": 2010005,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Capacitance",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 1643998
#    rate: 199999.99999999997
#    resolution: nan
#    starting_time: 13458.73396
#    starting_time_unit: Seconds
#    stimulus_description: Capacitance
#    sweep_number: 2010005
#    unit: A, 'index_059':
#  index_059 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (50997,), type "<f4">
#    description: {
#      "cycle_id": 2011001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Chirp test",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 50997
#    rate: 49999.99999999999
#    resolution: nan
#    starting_time: 13467.220999
#    starting_time_unit: Seconds
#    stimulus_description: Chirp test
#    sweep_number: 2011001
#    unit: A, 'index_060':
#  index_060 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (1999997,), type "<f4">
#    description: {
#      "cycle_id": 2012001,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Chirp",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 1999997
#    rate: 49999.99999999999
#    resolution: nan
#    starting_time: 13468.624119
#    starting_time_unit: Seconds
#    stimulus_description: Chirp
#    sweep_number: 2012001
#    unit: A, 'index_061':
#  index_061 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (1999997,), type "<f4">
#    description: {
#      "cycle_id": 2012002,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Chirp",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 1999997
#    rate: 49999.99999999999
#    resolution: nan
#    starting_time: 13508.981919
#    starting_time_unit: Seconds
#    stimulus_description: Chirp
#    sweep_number: 2012002
#    unit: A, 'index_062':
#  index_062 <class 'pynwb.icephys.CurrentClampStimulusSeries'>
#  Fields:
#    comments: no comments
#    conversion: 1e-12
#    data: <HDF5 dataset "data": shape (1999997,), type "<f4">
#    description: {
#      "cycle_id": 2012003,
#      "file": "H19.28.012.11.05.dat",
#      "group_label": "PGS4_190418_701_A01",
#      "series_label": "Chirp",
#      "sweep_label": ""
#  }
#    electrode: Electrode 0 <class 'pynwb.icephys.IntracellularElectrode'>
#    gain: 1.0
#    num_samples: 1999997
#    rate: 49999.99999999999
#    resolution: nan
#    starting_time: 13549.353719
#    starting_time_unit: Seconds
#    stimulus_description: Chirp
#    sweep_number: 2012003
#    unit: A}
